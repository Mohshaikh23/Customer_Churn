# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
def categorical_column_fetch(df):
    categorical_columns = []
    for i in df.columns:
        if df[i].dtype == 'object':
            categorical_columns.append(i)
            continue
        else:
            pass
    return categorical_columns

# %%
categorical_columns = categorical_column_fetch(df)
categorical_columns
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges',
#  'Churn']

# %%
new_df = df.iloc[:,1:]
new_df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
for i in new_df[cat]:
    print(new_df[i].value_counts())
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64
# ...

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
yes_data = df[df['Churn']=='Yes']

# %%
no_data = df[df['Churn']=='No']
no_data = no_data.sample(n=1869, random_state=24)

# %%
new_df = pd.concat([yes_data, no_data], ignore_index=True)
new_df.sample(frac=1, random_state = 24).reset_index(drop=True)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     9465-RWMXL    Male              0     Yes         No      32
# 1     2657-ALMWY  Female              1     Yes         No      26
# 2     2599-CZABP    Male              0     Yes         No      14
# 3     4154-AQUGT    Male              1     Yes         No      13
# 4     1837-YQUCE  Female              0      No         No      70
# ...          ...     ...            ...     ...        ...     ...
# 3733  4080-IIARD  Female              0     Yes         No      13
# 3734  6599-RCLCJ    Male              0     Yes         No      47
# 3735  5872-OEQNH  Female              0      No         No      60
# 3736  2430-USGXP    Male              0     Yes         No      24
# 3737  2761-OCIAX    Male              1      No         No       2
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             Yes               Yes     Fiber optic             No  ...
# ...

# %%
new_df['Churn'].value_counts()
# Out:
# Yes    1869
# No     1869
# Name: Churn, dtype: int64

# %%
new_df.drop('customerID', axis=1, inplace=True)

# %%
new_df[:5]
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0      No         No       2          Yes
# 1  Female              0      No         No       2          Yes
# 2  Female              0      No         No       8          Yes
# 3  Female              0     Yes         No      28          Yes
# 4    Male              0      No         No      49          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes          Yes               No
# 1            No     Fiber optic             No           No               No
# 2           Yes     Fiber optic             No           No              Yes
# 3           Yes     Fiber optic             No           No              Yes
# 4           Yes     Fiber optic             No          Yes              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
new_df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline

# Define the categorical columns to be encoded
categorical_columns = ['gender', 'Partner', 'Dependents', 'PhoneService',
                       'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
                       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
                       'Contract', 'PaperlessBilling', 'PaymentMethod']
target_column = ['Churn']

# Create the transformers for each type of preprocessing
categorical_transformer = Pipeline(steps=[
    ('one_hot_encoder', OneHotEncoder(drop='first'))
])
target_transformer = Pipeline(steps=[
    ('label_encoder', LabelEncoder())
])

# Create the ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('categorical', categorical_transformer, categorical_columns),
    ('target', target_transformer, target_column)
], remainder='passthrough')

# Apply the transformations to the specified columns
transformed_data = preprocessor.fit_transform(new_df)

# Get the transformed column names after one-hot encoding
transformed_column_names = preprocessor.transformers_[0][1]['one_hot_encoder'].get_feature_names_out(categorical_columns).tolist() + target_column

# Create a new DataFrame with the transformed data
df_transformed = pd.DataFrame(transformed_data, columns=transformed_column_names)

# Print the updated DataFrame
print(df_transformed)
print(transformed_column_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 27
#      21 preprocessor = ColumnTransformer(transformers=[
#      22     ('categorical', categorical_transformer, categorical_columns),
#      23     ('target', target_transformer, target_column)
#      24 ], remainder='passthrough')
#      26 # Apply the transformations to the specified columns
# ---> 27 transformed_data = preprocessor.fit_transform(new_df)
#      29 # Get the transformed column names after one-hot encoding
#      30 transformed_column_names = preprocessor.transformers_[0][1]['one_hot_encoder'].get_feature_names_out(categorical_columns).tolist() + target_column
#
# File D:\Applications\ANACONDA\ANACONDA_NAVIGATOR\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
# ...

# %%
new_df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       Male              0      No         No       2          Yes
# 1     Female              0      No         No       2          Yes
# 2     Female              0      No         No       8          Yes
# 3     Female              0     Yes         No      28          Yes
# 4       Male              0      No         No      49          Yes
# ...      ...            ...     ...        ...     ...          ...
# 3733    Male              0      No         No       1          Yes
# 3734  Female              0     Yes         No      52          Yes
# 3735    Male              0      No         No      21          Yes
# 3736    Male              0     Yes         No      37          Yes
# 3737  Female              1     Yes         No      72          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# ...
